# %%
# 在 VS Code 中观察 IPYNB 文件的大小要查看 .ipynb 文件
# 即显示Cell$ 信息的那个ipynb文件的实际大小，

# 您必须使用以下方法：在文件资源管理器中查看（最可靠）：


# 在 VS Code 左侧的文件浏览器中，对该 .ipynb 文件右键点击。

# 选择 “在资源管理器中显示” (Reveal in File Explorer)。
# 在 $\text{Windows}$ 资源管理器中，您可以直接看到文件的大小。
