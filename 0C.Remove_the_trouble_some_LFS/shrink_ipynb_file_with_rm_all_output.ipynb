# %% [markdown]
# 打开键盘快捷键设置：按下快捷键： Ctrl + K  然后 Ctrl + S。
# 或者，通过菜单栏：File (文件) \ Preferences (首选项) \Keyboard Shortcuts (键盘快捷键)。

# %% [markdown]
# alt + Del # clear all output from One specific cell

# %%
print( "Hello, world!" )

# %% [markdown]
# ######
# alt + x + Del # clear all output from the whole ipynb file

# %%
print( "Hello, world!" )

# %% [markdown]
# VS Code 的Jupyter Notebook 或其他交互式窗口中，有几种方法可以方便地复制连续的多个Cell（单元格）。这主要取决于您是想在命令模式 (Command Mode) 还是 编辑模式 (Edit Mode) 下操作。

# %% [markdown]
# 📌 使用鼠标和Shift 键（类似文件管理器）这与您在Windows 文件管理器中选择多个连续文件的方式类似。
#
# 点击 您想要选择的第一个Cell。按住Shift 键。点
#
# 击 您想要选择的最后一个Cell。
#
# 此时，第一个和最后一个Cell 之间的所有Cell 都会被选中。
#
#
# 然后可以松开Shift 键。
# 按下Ctrl + C 复制所有选中的Cell。
# 按下Ctrl + V 复制所有选中的Cell。
#
# 也可以直接鼠标右键复制 再粘贴

# %% [markdown]
# 📌 使用鼠标和Ctrl 键（选择非连续Cell）
# 如果您需要选择非连续的Cell，可以使用Ctrl 键。点击 您想要选择的第一个Cell。按住Ctrl 键。用鼠标依次点击所有您想选中的Cell。
#
#
# 按下Ctrl} + {C 复制所有选中的Cell。、
#
#
# 或者 方法二（鼠标 $+{Shift 键）。非连续复制： 推荐使用 方法三（鼠标 $+{Ctrl 键）。
