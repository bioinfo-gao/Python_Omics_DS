# %% [markdown]
# !conda create -n bioPy312 python=3.12  -y

# %% [markdown]
# %conda is an IPython magic command.
# !conda (Shell Command):

# %%
# %conda install numpy pandas scikit-learn matplotlib seaborn scanpy -c conda-forge -y
# Out:
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\zhen-\anaconda3\envs\bioPy312
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scanpy
#     - scikit-learn
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anndata-0.12.4             |     pyhd8ed1ab_0         130 KB  conda-forge
#     array-api-compat-1.12.0    |     pyhe01879c_0          45 KB  conda-forge
#     contourpy-1.3.3            |  py312hf90b1b7_2         220 KB  conda-forge
#     crc32c-2.8                 |  py312he5662c2_0         134 KB  conda-forge
#     deprecated-1.3.1           |     pyhd8ed1ab_0          15 KB  conda-forge
#     donfig-0.8.1.post1         |     pyhd8ed1ab_1          22 KB  conda-forge
# ...

# %%
import  pandas  as  pd
# 创建 DataFrame
data = {
        'Gene': ['Gene1', 'Gene2'],
        'Cell1': [10, 0],
        'Cell2': [3, 5]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Gene  Cell1  Cell2
# 0  Gene1     10      3
# 1  Gene2      0      5
