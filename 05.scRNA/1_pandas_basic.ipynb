# %% [markdown]
# https://cloud.tencent.com/developer/article/2490262

# %% [markdown]
# !conda create -n bioPy312 python=3.12  -y

# %% [markdown]
# %conda is an IPython magic command.
# !conda (Shell Command):

# %%
import  pandas  as  pd
# 创建 DataFrame
data = {
        'Gene': ['Gene1', 'Gene2'],
        'Cell1': [10, 0],
        'Cell2': [3, 5]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Gene  Cell1  Cell2
# 0  Gene1     10      3
# 1  Gene2      0      5

# %%
import  numpy  as  np
# 创建 NumPy 数组
array = np.array([
        [1, 2, 3],
        [4, 5, 6]
])
print(array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# 读取数据
# df = pd.read_csv('data.csv')
# 数据清洗
# df.dropna(inplace=True)

# %%
# 数组运算
array = np.array([1, 2, 3])
array = array * 2
print(array)
# Out:
# [2 4 6]

# %%
import scanpy as sc

# %%
# 读取数据
adata = sc.read_10x_h5('filtered_feature_bc_matrix.h5')
# Out:
# c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
# 预处理
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
# 识别标记基因
# 识别标记基因
# 识别标记基因
# 识别标记基因
# 识别标记基因


sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
# 可视化标记基因
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'leiden'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 识别标记基因
# ----> 2 sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
#       3 # 可视化标记基因
#       4 sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\legacy_api_wrap\__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:679, in rank_genes_groups(adata, groupby, mask_var, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     669 adata.uns[key_added] = {}
#     670 adata.uns[key_added]["params"] = dict(
#     671     groupby=groupby,
#     672     reference=reference,
#    (...)    676     corr_method=corr_method,
#     677 )
# --> 679 test_obj = _RankGenes(
#     680     adata,
#     681     groups_order,
#     682     groupby,
#     683     mask_var=mask_var,
#     684     reference=reference,
#     685     use_raw=use_raw,
#     686     layer=layer,
#     687     comp_pts=pts,
#     688 )
#     690 if check_nonnegative_integers(test_obj.X) and method != "logreg":
#     691     logg.warning(
#     692         "It seems you use rank_genes_groups on the raw count data. "
#     693         "Please logarithmize your data before calling rank_genes_groups."
#     694     )
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:143, in _RankGenes.__init__(self, adata, groups, groupby, mask_var, reference, use_raw, layer, comp_pts)
#     140 else:
#     141     self.expm1_func = np.expm1
# --> 143 self.groups_order, self.groups_masks_obs = _utils.select_groups(
#     144     adata, groups, groupby
#     145 )
#     147 # Singlet groups cause division by zero errors
#     148 invalid_groups_selected = set(self.groups_order) & set(
#     149     adata.obs[groupby].value_counts().loc[lambda x: x < 2].index
#     150 )
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\scanpy\_utils\__init__.py:845, in select_groups(adata, groups_order_subset, key)
#     839 def select_groups(
#     840     adata: AnnData,
#     841     groups_order_subset: Iterable[str] | Literal["all"] = "all",
#     842     key: str = "groups",
#     843 ) -> tuple[list[str], NDArray[np.bool_]]:
#     844     """Get subset of groups in adata.obs[key]."""
# --> 845     groups_order = adata.obs[key].cat.categories
#     846     if f"{key}_masks" in adata.uns:
#     847         groups_masks_obs = adata.uns[f"{key}_masks"]
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'leiden'
