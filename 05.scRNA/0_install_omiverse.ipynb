# %% [markdown]
# python -c "import torch; print(torch.__version__)"
#
# <!-- C:\Users\zhen-\anaconda3\envs\sc_omics\Lib\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#
#   import pynvml  # type: ignore[import] -->
#
# 2.5.1+cu121

# %% [markdown]
# nvcc --version
# <!-- nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0 -->

# %%
好的，非常感谢您提供准确的 PyTorch 版本号！

您的 PyTorch 版本是 2.5.1，并且它是针对 CUDA 12.1 编译的 (cu121)。

这是导致 torch-scatter 和 torch-cluster 导入失败的根本原因。您之前运行的 PyG 依赖安装命令中的 URL 链接版本不匹配。

# %%
✅ 最终解决方案：使用精确匹配的版本安装 PyG 依赖
我们将使用您的精确版本 2.5.1+cu121 来确保 C++ 扩展正确编译和链接。

# %%
请在您的激活环境 (sc_omics) 中，执行以下步骤：

步骤 1: 清理损坏的 PyG 尝试
首先，彻底移除任何之前安装失败或损坏的 PyG 依赖：

Bash
pip uninstall torch_geometric torch-scatter torch-cluster -y
步骤 2: 严格安装 PyG 核心依赖
我们将使用精确的 PyTorch 版本（2.5.1）和 CUDA 版本（121）来安装 PyG 的底层依赖。

请运行以下所有命令：

安装 torch-scatter:

Bash
pip install torch-scatter -f https://data.pyg.org/whl/torch-2.5.1+cu121.html
安装 torch-cluster:

Bash
pip install torch-cluster -f https://data.pyg.org/whl/torch-2.5.1+cu121.html
安装 torch-geometric 主包:

Bash
pip install torch_geometric
步骤 3: 最终验证 🚀
在所有依赖安装成功后，请最后一次进入 Python 交互模式并验证 omicverse 的导入：

Bash
python
Python
>>> import omicverse as ov
