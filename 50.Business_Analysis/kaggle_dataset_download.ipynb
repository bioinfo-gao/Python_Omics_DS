# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from kagglehub) (2.32.5)
# Collecting tqdm (from kagglehub)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\zhen-\anaconda3\envs\dsp3.10\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
#
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-0.3.13 tqdm-4.67.1

# %% [markdown]
# C:\Users\zhen-\.cache\kagglehub\datasets\iamsouravbanerjee\customer-shopping-trends-dataset\versions\2

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iamsouravbanerjee/customer-shopping-trends-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/iamsouravbanerjee/customer-shopping-trends-dataset?dataset_version_number=2...
# 100%|██████████| 146k/146k [00:00<00:00, 780kB/s]
# Extracting files...
# Path to dataset files: C:\Users\zhen-\.cache\kagglehub\datasets\iamsouravbanerjee\customer-shopping-trends-dataset\versions\2
