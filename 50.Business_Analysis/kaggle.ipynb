# %% [markdown]
# # Presentation Link : https://docs.google.com/presentation/d/1kG4E8Aw_DVIBjRLB3B-UlPrPJBKlJYF-/present

# %%
# !pip install plotly -y
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 5.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 4.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 4.3 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 4.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 6.0 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 7.8 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
# ...

# %% [markdown]
# # Import Important Libraries

# %%
import pandas            as pd 
import numpy             as np 
import matplotlib.pyplot as plt 
import seaborn           as sns 
import plotly.express    as px 
import warnings 

warnings.filterwarnings("ignore")

# %%
##df = pd.read_csv("/Users/zhen-/.kaggle/datasets/shopping-dataset/shopping_trends.csv")
df = pd.read_csv("C:/Users/zhen-/.cache/kagglehub/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/versions/2/shopping_trends_updated.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.shape
# Out:
# (3900, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer ID                3900 non-null   int64
#  1   Age                        3900 non-null   int64
#  2   Gender                     3900 non-null   object
#  3   Item Purchased             3900 non-null   object
#  4   Category                   3900 non-null   object
#  5   Purchase Amount (USD)      3900 non-null   int64
#  6   Location                   3900 non-null   object
#  7   Size                       3900 non-null   object
#  8   Color                      3900 non-null   object
#  9   Season                     3900 non-null   object
#  10  Review Rating              3900 non-null   float64
#  11  Payment Method             3900 non-null   object
#  12  Shipping Type              3900 non-null   object
# ...

# %%
df.columns.to_list()
# Out:
# ['Customer ID',
#  'Age',
#  'Gender',
#  'Item Purchased',
#  'Category',
#  'Purchase Amount (USD)',
#  'Location',
#  'Size',
#  'Color',
#  'Season',
#  'Review Rating',
#  'Payment Method',
#  'Shipping Type',
#  'Previous Purchases',
#  'Preferred Payment Method',
#  'Frequency of Purchases',
#  'Customer Segmentation',
#  'Seasonal Trends',
#  'Delivery Time',
#  'Number of Items Purchased']

# %%
lis = [
    "Gender" , "Item Purchased" ,"Category" ,"Size" , "Color" , "Season" , 
    "Payment Method" , "Shipping Type" , "Preferred Payment Method" ,  'Frequency of Purchases']

for i in lis : 
    print(i , df[i].unique())
    print()
# Out:
# Gender ['Male' 'Female']
#
# Item Purchased ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
#
# Category ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
#
# Size ['L' 'S' 'M' 'XL']
#
# Color ['Gray' 'Maroon' 'Turquoise' 'White' 'Charcoal' 'Silver' 'Pink' 'Purple'
#  'Olive' 'Gold' 'Violet' 'Teal' 'Lavender' 'Black' 'Green' 'Peach' 'Red'
#  'Cyan' 'Brown' 'Beige' 'Orange' 'Indigo' 'Yellow' 'Magenta' 'Blue']
#
# Season ['Winter' 'Spring' 'Summer' 'Fall']
#
# Payment Method ['Credit Card' 'Bank Transfer' 'Cash' 'PayPal' 'Venmo' 'Debit Card']
#
# Shipping Type ['Express' 'Free Shipping' 'Next Day Air' 'Standard' '2-Day Shipping'
#  'Store Pickup']
#
# Preferred Payment Method ['Venmo' 'Cash' 'Credit Card' 'PayPal' 'Bank Transfer' 'Debit Card']
#
# ...

# %%
df.set_index("Customer ID" , inplace=True)

# %%
df.head()
# Out:
#              Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# Customer ID
# 1             55   Male         Blouse  Clothing                     53
# 2             19   Male        Sweater  Clothing                     64
# 3             50   Male          Jeans  Clothing                     73
# 4             21   Male        Sandals  Footwear                     90
# 5             45   Male         Blouse  Clothing                     49
#
#                   Location Size      Color  Season  Review Rating  \
# Customer ID
# 1                 Kentucky    L       Gray  Winter            3.1
# 2                    Maine    L     Maroon  Winter            3.1
# 3            Massachusetts    S     Maroon  Spring            3.1
# 4             Rhode Island    M     Maroon  Spring            3.5
# 5                   Oregon    M  Turquoise  Spring            2.7
#
#             Payment Method  Shipping Type  Previous Purchases  \
# Customer ID
# ...

# %%
df.tail() # Gender Sorted Male The Female
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
#                Location Size      Color  Season  Review Rating Payment Method  \
# Customer ID
# 3896           Virginia    L  Turquoise  Summer            4.2           Cash
# 3897               Iowa    L      White  Spring            4.5         PayPal
# 3898         New Jersey    L      Green  Spring            2.9    Credit Card
# 3899          Minnesota    S      Brown  Summer            3.8         PayPal
# 3900         California    M      Beige  Spring            3.1  Bank Transfer
#
# ...

# %%
df.info() # No Miising Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 1 to 3900
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        3900 non-null   int64
#  1   Gender                     3900 non-null   object
#  2   Item Purchased             3900 non-null   object
#  3   Category                   3900 non-null   object
#  4   Purchase Amount (USD)      3900 non-null   int64
#  5   Location                   3900 non-null   object
#  6   Size                       3900 non-null   object
#  7   Color                      3900 non-null   object
#  8   Season                     3900 non-null   object
#  9   Review Rating              3900 non-null   float64
#  10  Payment Method             3900 non-null   object
#  11  Shipping Type              3900 non-null   object
#  12  Previous Purchases         3900 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe() # No Outliers
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases  \
# count  3900.000000            3900.000000    3900.000000         3900.000000
# mean     44.068462              59.764359       3.749949           25.351538
# std      15.207589              23.685392       0.716223           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.700000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000
#
#        Delivery Time  Number of Items Purchased
# count    3900.000000                3900.000000
# mean       15.952308                   4.998974
# std         8.282848                   2.555764
# min         2.000000                   1.000000
# ...

# %%
plt.figure(figsize= (12,8))
plt.title("Distribtion Of Age")

sns.histplot(data=df  , x= "Age" , bins= 15)
plt.xlabel("Age")

plt.ylabel("Frequency")
plt.savefig("Distribtion Of Age.png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %% [markdown]
# Uniform Distribtion

# %% [markdown]
# 注：这个plotly 代码是动态，点击各条线可以显示详细信息。

# %%
fig = px.box(df , x = "Age" , title= "Box Of Age") # from plotly  
fig.show()

# %% [markdown]
# Most of the ages are concentrated between 31 and 57 years old.

# %%
df[df["Age"] == df["Age"].max()]
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 40            70    Male          Pants     Clothing                     60
# 109           70    Male          Socks     Clothing                     79
# 115           70    Male           Coat    Outerwear                     95
# 204           70    Male          Scarf  Accessories                     38
# 230           70    Male        Sandals     Footwear                     28
# ...          ...     ...            ...          ...                    ...
# 3676          70  Female            Hat  Accessories                     80
# 3803          70  Female          Scarf  Accessories                     72
# 3819          70  Female       Sneakers     Footwear                     41
# 3823          70  Female            Hat  Accessories                     41
# 3875          70  Female        Sweater     Clothing                     54
#
# ...

# %% [markdown]
# There are 67 men and women who are the oldest shoppers, with an age of 70 years.

# %%
df[df["Age"] == df["Age"].min()]
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 25            18    Male         Jacket    Outerwear                     22
# 26            18    Male         Hoodie     Clothing                     25
# 73            18    Male          Dress     Clothing                     26
# 229           18    Male          Socks     Clothing                     79
# 358           18    Male           Belt  Accessories                     56
# ...          ...     ...            ...          ...                    ...
# 3611          18  Female         Jacket    Outerwear                     86
# 3715          18  Female            Hat  Accessories                     31
# 3726          18  Female          Dress     Clothing                    100
# 3807          18  Female          Boots     Footwear                     71
# 3869          18  Female          Dress     Clothing                     29
#
# ...

# %% [markdown]
# There are 69 men and women who are the Youngest shoppers, with an age of 18 years.

# %%
plt.figure(figsize= (12,8))
plt.title("Distribtion Of Purchased Amount(USD)")
sns.histplot(data=df  , x= "Purchase Amount (USD)" , bins= 15)
plt.xlabel("Purchase Amount (USD)")
plt.ylabel("Frequency")
plt.savefig("Distribtion Of Purchased Amount(USD).png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %% [markdown]
# Uniform Distribution

# %%
fig = px.box(df , x = "Purchase Amount (USD)" , title= "Box Of Purchase Amount (USD)")
fig.show()

# %% [markdown]
# Most of the purchase amounts are concentrated between 39 and 81 USD.

# %%
df[df["Purchase Amount (USD)"] == df["Purchase Amount (USD)"].max()]
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 43            20    Male           Coat    Outerwear                    100
# 96            37    Male       Sneakers     Footwear                    100
# 194           36    Male           Belt  Accessories                    100
# 205           24    Male       Sneakers     Footwear                    100
# 244           25    Male        Jewelry  Accessories                    100
# 249           47    Male           Belt  Accessories                    100
# 456           54    Male         Blouse     Clothing                    100
# 519           24    Male         Blouse     Clothing                    100
# 582           32    Male        Sweater     Clothing                    100
# 616           67    Male        Sandals     Footwear                    100
# 770           52    Male          Socks     Clothing                    100
# ...

# %% [markdown]
# There are 36 men and women who have the highest purchase value, with a purchase amount of 100 USD.

# %%
df[df["Purchase Amount (USD)"] == df["Purchase Amount (USD)"].min()]
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 6             46    Male       Sneakers     Footwear                     20
# 27            38    Male        Jewelry  Accessories                     20
# 53            42    Male        T-shirt     Clothing                     20
# 256           43    Male          Scarf  Accessories                     20
# 295           70    Male          Skirt     Clothing                     20
# 342           20    Male            Hat  Accessories                     20
# 445           48    Male          Dress     Clothing                     20
# 508           65    Male         Shorts     Clothing                     20
# 509           27    Male        Jewelry  Accessories                     20
# 587           45    Male         Hoodie     Clothing                     20
# 638           21    Male        Sweater     Clothing                     20
# ...

# %% [markdown]
# There are 52 men and women who have the Lowest purchase value, with a purchase amount of 20 USD.

# %% [markdown]
# ### Key Observations
#
# Most of the ages are concentrated between 31 and 57 years old.
#
# There are 67 men and women who are the oldest shoppers, aged 70 years.
#
# There are 69 men and women who are the youngest shoppers, aged 18 years.
#
# Most purchase amounts are concentrated between 39 and 81 USD.
#
# There are 36 men and women who have the highest purchase value, with a purchase amount of 100 USD.
#
# There are 52 men and women who have the lowest purchase value, with a purchase amount of 20 USD.
#
# Most of the review ratings are concentrated between 3.1 and 4.4.
#
# The highest review rating is 5.0, while the lowest review rating is 2.5.
#
# Most of the previous purchases are concentrated between 13 and 38 purchases.
#
# The highest number of previous purchases is 50, while the lowest is 1.

# %%
plt.figure(figsize = (20, 6))
plt.scatter(df['Age'], df['Review Rating'], alpha=0.1)
plt.title('Age vs. Review Rating')
plt.xlabel('Age')
plt.ylabel('Review Rating')
plt.show()

# %%
fig = px.scatter(
    df , x = "Age" , y = "Purchase Amount (USD)" , color= "Gender" ,
     title= "Realtion Brtween Age And Purchased Amount (USD)")
fig.show()

# %% [markdown]
# Age does not have a strong influence on purchase amount; customers of all ages make purchases across the full range of prices.

# %%
df
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
df.describe(include= "O")
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Payment Method  Shipping Type Preferred Payment Method  \
# count            3900           3900                     3900
# unique              6              6                        6
# top       Credit Card  Free Shipping                   PayPal
# freq              696            675                      677
#
#        Frequency of Purchases Customer Segmentation     Seasonal Trends
# count                    3900                  3900                3900
# unique                      7                     3                   4
# top            Every 3 Months                   New  Summer preperation
# ...

# %%
gender_counts = df['Gender'].value_counts()
print(gender_counts) 
plt.figure(figsize=(12,8))
plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True ,
    colors=['skyblue', 'lightcoral'] 
)
plt.title("Gender Frequency")
plt.savefig("Gender Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Gender" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
print(x) 
plt.figure (figsize= (12,8))
plt.title("Average Purchase Amount (USD) For Each Gender")
plt.pie(x["Purchase Amount (USD)"] , labels= x["Gender"] , autopct= "%1.1f%%" , startangle= 90 , colors= ["skyblue" , "lightcoral"] , shadow = True)
plt.savefig("Average Purchase Amount (USD) For Each Gender.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
#    Gender  Purchase Amount (USD)
# 0  Female              60.249199
# 1    Male              59.536199

# %% [markdown]
# There are 2,652 men (68%) and 1,248 women (32%) in the dataset.
# The average purchase amount for men is 59.54 USD, with a median of 49.7 USD.
# The average purchase amount for women is 60.25 USD, with a median of 50.3 USD.
#
# ### Insights
# Although men make up a larger portion of the customer base, average spending is very similar between genders.
# Both men and women tend to purchase within a similar range, indicating that gender does not strongly affect purchase amount.
# The distribution is fairly balanced around the mean values, suggesting no major skew in spending habits by gender.

# %%
item_order = df['Item Purchased'].value_counts().index

plt.figure(figsize=(12,8))
plt.title("Count Of Item Purchased")

ax = sns.countplot(
    data=df,
    x="Item Purchased",
    palette="plasma",
    order=item_order
)

plt.xlabel("Item Purchased")
plt.ylabel("Count")
plt.xticks(rotation=90)

for i in ax.containers:
    ax.bar_label(i)

plt.tight_layout()
plt.savefig("Count Of Item Purchased.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
x = df.pivot_table(index= "Item Purchased" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#    Item Purchased  Purchase Amount (USD)
# 24        T-shirt              62.911565
# 3           Boots              62.625000
# 5           Dress              62.168675
# 17          Shoes              61.600000
# 16          Shirt              61.136095
# 15          Scarf              60.898089
# 2          Blouse              60.877193
# 8             Hat              60.876623
# 11          Jeans              60.870968
# 6          Gloves              60.550000
# 0        Backpack              60.391608
# 18         Shorts              60.082803
# 22     Sunglasses              59.931677
# 1            Belt              59.844720
# 20       Sneakers              59.551724
# 19          Skirt              59.506329
# 13          Pants              59.005848
# 12        Jewelry              58.538012
# 21          Socks              58.188679
# 9          Hoodie              58.059603
# 7         Handbag              57.888889
# 23        Sweater              57.695122
# ...

# %%
fig = px.bar(x , x = "Item Purchased" , y = "Purchase Amount (USD)" , color= "Item Purchased" , title= "Average Purchase Amount by Item Purchased" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# # Average Purchase Amount by Item Purchased
#
# **Summary of top insights based on the dataset:**
#
# - **Most frequently purchased items** are **Blouse, Jewelry, and Pants**, each with **171 purchases**.
#
# - **Items with the highest average purchase amount:**
#   - **T-shirt:** 62.91 USD
#   - **Boots:** 62.63 USD
#   - **Dress:** 62.17 USD
#
# - **Items with the lowest average purchase amount:**
#   - **Jacket:** 56.74 USD
#   - **Sandals:** 57.50 USD
#   - **Coat:** 57.61 USD
#
# ## Insights
#
# - Most purchased items do not necessarily have the highest purchase amounts, indicating that **popularity and price are not directly correlated**.
# - **T-shirt, Boots, and Dress** have the highest average spending, suggesting they may represent **premium items** or items customers are willing to spend more on.
# - Items like **Jacket, Sandals, and Coat** are purchased frequently at **lower average prices**, reflecting more **affordable or essential items**.
# - Overall, purchase amounts across all items are relatively close, mostly ranging between **56.7 USD and 62.9 USD**, indicating a **mid-range pricing strategy**.

# %%
category_counts = df['Category'].value_counts()
print(category_counts) 
plt.figure(figsize=(12,8))
plt.pie(
    category_counts,
    labels=category_counts.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Category Frequeny")
plt.savefig("Category Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Category" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x

# %%
x.describe()
# Out:
#        Purchase Amount (USD)
# count              25.000000
# mean               59.802010
# std                 1.701748
# min                56.742331
# 25%                58.188679
# 50%                59.931677
# 75%                60.877193
# max                62.911565

# %%
x.head()
# Out:
#    Item Purchased  Purchase Amount (USD)
# 24        T-shirt              62.911565
# 3           Boots              62.625000
# 5           Dress              62.168675
# 17          Shoes              61.600000
# 16          Shirt              61.136095

# %%
plt.figure(figsize=(12,8))
plt.pie(
    x["Purchase Amount (USD)"],
    #labels=x["Category"],
    labels=x["Item Purchased"],
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Average Purchase Amount (USD) For Each Category")
plt.savefig("Average Purchase Amount (USD) For Each Category.png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %% [markdown]
# ###  Average Purchase Amount by Category
#
# **Summary of top insights based on the dataset:**
#
# - **frequently purchased category:**
#   - **Clothing**: 1,737 purchases
#   - **Accessories**: 1,240 purchases
#   - **Footwear**: 599 purchases
#   - **Outerwear**: 324 purchases
#
# - **Categories with the average purchase amount:**
#   - **Footwear**: 60.26 USD
#   - **Clothing**: 60.03 USD
#   - **Accessories**: 59.84 USD
#   - **Outerwear**: 57.17 USD
#
# ###  Insights
#
# - **Clothing dominates in terms of purchase frequency**, but **Footwear has the highest average spending per purchase**, suggesting it is **more premium or higher-value items**.
# - **Outerwear**, while the least purchased category, has a **lower average purchase amount**, indicating these items may be **less expensive or seasonal**.
# - Overall, **purchase amounts across all categories are relatively close**, mostly between **57 USD and 60.3 USD**, indicating a **consistent mid-range pricing strategy across categories**.

# %%
size = df['Size'].value_counts()
print(size) 
plt.figure(figsize=(12,8))
plt.pie(
    size,
    labels=size.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Size Frequency")
plt.savefig("Size Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Size" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#   Size  Purchase Amount (USD)
# 2    S              61.037707
# 3   XL              60.090909
# 1    M              59.924217
# 0    L              58.563153

# %%
plt.figure(figsize=(12,8))
plt.pie(
    x["Purchase Amount (USD)"],
    labels=x["Size"],
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Average Purchase Amount (USD) For Each Size")
plt.savefig("Average Purchase Amount (USD) For Each Size.png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### Average Purchase Amount by Size
#
# - **frequently purchased sizes:**
#   - **M**: 1,755 purchases
#   - **L**: 1,053 purchases
#   - **S**: 663 purchases
#   - **XL**: 429 purchases
#
# - **Sizes with the average purchase amount:**
#   - **S**: 61.04 USD
#   - **XL**: 60.09 USD
#   - **M**: 59.92 USD
#   - **L**: 58.56 USD
#
# ### Insights
#
# - **Size M is the most popular**, but **Size S has the highest average spending**, suggesting customers buying smaller sizes may spend slightly more per purchase.
# - **Size L**, while frequently purchased, has the **lowest average purchase amount**, indicating it may be associated with more **affordable or bulk items**.
# - Overall, **purchase amounts across sizes are relatively close**, ranging roughly from **58.6 USD to 61 USD**, showing a **consistent mid-range pricing pattern** regardless of size.

# %%
season = df['Season'].value_counts()
print(season) 
plt.figure(figsize=(12,8))
plt.pie(
    season,
    labels=season.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Season Frequency")
plt.savefig("Season Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Season" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#    Season  Purchase Amount (USD)
# 0    Fall              61.556923
# 3  Winter              60.357364
# 1  Spring              58.737738
# 2  Summer              58.405236

# %%
plt.figure(figsize=(12,8))
plt.pie(
    x["Purchase Amount (USD)"],
    labels=x["Season"],
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True , 
    colors = ["skyblue", "lightcoral", "gold", "mediumseagreen"]
)
plt.title("Average Purchase Amount (USD) For Each Season")
plt.savefig("Average Purchase Amount (USD) For Each Season.png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### Average Purchase Amount by Season
#
# - **Frequency purchases by season:**
#   - **Spring**: 999 purchases
#   - **Fall**: 975 purchases
#   - **Winter**: 971 purchases
#   - **Summer**: 955 purchases
#
# - **Seasons with the average purchase amount:**
#   - **Fall**: 61.56 USD
#   - **Winter**: 60.36 USD
#   - **Spring**: 58.74 USD
#   - **Summer**: 58.41 USD
#
# ### Insights
#
# - **Fall and Winter purchases have higher average spending** compared to Spring and Summer, indicating **customers tend to spend more on seasonal items during colder months**.
# - **Spring and Summer are the most frequent seasons for purchases**, but the average purchase amount is slightly lower, suggesting **lighter or less expensive seasonal products**.
# - Overall, **purchase amounts across seasons are relatively close**, ranging roughly between **58.4 USD and 61.6 USD**, showing a **consistent mid-range pricing pattern** throughout the year.

# %%
df.head
#df['Subscription Status'].value_counts()
# Out:
# <bound method NDFrame.head of       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
SubscribtionStatus_counts = df['Subscription Status'].value_counts() # <<< 这个需要新数据，原数据集有两个版本
print(SubscribtionStatus_counts) 
plt.figure(figsize=(12,8))
plt.pie(
    SubscribtionStatus_counts,
    labels=SubscribtionStatus_counts.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True ,
    colors=['skyblue', 'lightcoral'] 
)
plt.title("Subscription Status Frequency")
plt.savefig("Subscribtion Status Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Subscription Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Subscription Status" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
print(x) 
plt.figure (figsize= (12,8))
plt.title("Average Purchase Amount (USD) For Each Subscription Status")
plt.pie(x["Purchase Amount (USD)"] , labels= x["Subscription Status"] , autopct= "%1.1f%%" , startangle= 90 , colors= ["skyblue" , "lightcoral"] , shadow = True)
plt.savefig("Average Purchase Amount (USD) For Each Subscription Status.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
#   Subscription Status  Purchase Amount (USD)
# 0                  No              59.865121
# 1                 Yes              59.491928

# %% [markdown]
# ### Average Purchase Amount by Subscription Status
#
# **Summary of top insights based on the dataset:**
#
# - **Number of customers by subscription status:**
#   - **No**: 2,847 customers
#   - **Yes**: 1,053 customers
#
# - **Average purchase amount by subscription status:**
#   - **No**: 59.87 USD
#   - **Yes**: 59.49 USD
#
# ### Insights
#
# - **The majority of customers are not subscribed** (68%), while 32% have a subscription.
# - **Average spending is very similar** between subscribed and non-subscribed customers, indicating that **having a subscription does not significantly affect purchase amount**.
# - This suggests that **subscriptions may be more useful for customer engagement or loyalty programs** rather than directly increasing the purchase value.

# %%
Discount_Applied_counts = df['Discount Applied'].value_counts()
print(Discount_Applied_counts) 
plt.figure(figsize=(12,8))
plt.pie(
    Discount_Applied_counts,
    labels=Discount_Applied_counts.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True ,
    colors=['skyblue', 'lightcoral'] 
)
plt.title("Discount Applied Frequency")
plt.savefig("Discount Applied Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Discount Applied
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Discount Applied" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
print(x) 
plt.figure (figsize= (12,8))
plt.title("Average Purchase Amount (USD) For Each Discount Applied")
plt.pie(x["Purchase Amount (USD)"] , labels= x["Discount Applied"] , autopct= "%1.1f%%" , startangle= 90 , colors= ["skyblue" , "lightcoral"] , shadow = True)
plt.savefig("Average Purchase Amount (USD) For Each Discount Applied.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
#   Discount Applied  Purchase Amount (USD)
# 0               No              60.130454
# 1              Yes              59.279070

# %% [markdown]
# ###  Average Purchase Amount by Discount Applied
#
# - **Number of purchases by discount application:**
#   - **No Discount**: 2,223 purchases
#   - **Discount Applied**: 1,677 purchases
#
# - **Average purchase amount by discount status:**
#   - **No Discount**: 60.13 USD
#   - **Discount Applied**: 59.28 USD
#
# ### Insights
#
# - **Most purchases are made without a discount** (57%), while 43% of purchases apply a discount.
# - **Average spending is slightly higher when no discount is applied**, indicating that **customers may purchase slightly more expensive items when full price is paid**.
# - Discounts appear to encourage **more frequent or bulk purchases** but slightly **reduce the average transaction value per purchase**.

# %%
Promo_Code_Used_counts = df['Promo Code Used'].value_counts()
print(Promo_Code_Used_counts) 
plt.figure(figsize=(12,8))
plt.pie(
    Promo_Code_Used_counts,
    labels=Promo_Code_Used_counts.index,
    autopct='%1.1f%%', 
    startangle=90,
    shadow= True ,
    colors=['skyblue', 'lightcoral'] 
)
plt.title("Promo Code Used Frequency")
plt.savefig("Promo Code Used Frequency.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Promo Code Used
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Promo Code Used" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
print(x) 
plt.figure (figsize= (12,8))
plt.title("Average Purchase Amount (USD) For Each Promo Code Used")
plt.pie(x["Purchase Amount (USD)"] , labels= x["Promo Code Used"] , autopct= "%1.1f%%" , startangle= 90 , colors= ["skyblue" , "lightcoral"] , shadow = True)
plt.savefig("Average Purchase Amount (USD) For Each Promo Code Used.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
#   Promo Code Used  Purchase Amount (USD)
# 0              No              60.130454
# 1             Yes              59.279070

# %% [markdown]
# ### Average Purchase Amount by Promo Code Usage
# - **Number of purchases by promo code usage:**
#   - **No Promo Code**: 2,223 purchases
#   - **Promo Code Used**: 1,677 purchases
#
# - **Average purchase amount by promo code status:**
#   - **No Promo Code**: 60.13 USD
#   - **Promo Code Used**: 59.28 USD
#
# ### Insights
# - **Most purchases are made without using a promo code** (57%), while 43% of purchases use a promo code.
# - **Average spending is slightly higher when no promo code is used**, suggesting that **promo codes may encourage customers to purchase more frequently but with slightly lower transaction values**.
# - Promo codes appear to be an effective tool for **driving engagement and sales**, even if they slightly reduce the average purchase amount.

# %%
Payment_Method_order = df['Payment Method'].value_counts().index
print(df['Payment Method'].value_counts())

plt.figure(figsize=(12,8))
plt.title("Count Of Payment Method")

ax = sns.countplot(
    data=df,
    x="Payment Method",
    palette="plasma",
    order=Payment_Method_order
)

plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.xticks(rotation=45)

for i in ax.containers: 
    ax.bar_label(i)

plt.tight_layout()
plt.savefig("Count Of Payment Method.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Payment Method" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#   Payment Method  Purchase Amount (USD)
# 3     Debit Card              60.915094
# 2    Credit Card              60.074516
# 0  Bank Transfer              59.712418
# 1           Cash              59.704478
# 4         PayPal              59.245199
# 5          Venmo              58.949527

# %%
fig = px.bar(x , x = "Payment Method" , y = "Purchase Amount (USD)" , color= "Payment Method", title= "Average Purchase Amount (USD) For Each Payment Method" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# ### Average Purchase Amount by Payment Method
# - **Number of purchases by payment method:**
#   - **Credit Card**: 696 purchases
#   - **Venmo**: 653 purchases
#   - **Cash**: 648 purchases
#   - **PayPal**: 638 purchases
#   - **Debit Card**: 633 purchases
#   - **Bank Transfer**: 632 purchases
#
# - **Average purchase amount by payment method:**
#   - **Venmo**: 61.24 USD
#   - **Credit Card**: 61.16 USD
#   - **Cash**: 59.93 USD
#   - **Bank Transfer**: 58.74 USD
#   - **PayPal**: 58.70 USD
#   - **Debit Card**: 58.64 USD
#
# ### Insights
#
# - **Credit Card is the most commonly used payment method**, closely followed by Venmo and Cash.
# - **Highest average spending occurs with Venmo and Credit Card**, suggesting customers using these methods may prefer higher-value purchases.
# - **Bank Transfer, PayPal, and Debit Card** show slightly lower average purchase amounts, indicating these methods are used more for **regular or smaller transactions**.
# - Overall, **payment method influences average spending slightly**, but all methods fall within a relatively narrow range (**58.6 USD – 61.2 USD**).

# %%
Shipping_Type_order = df['Shipping Type'].value_counts().index
print(df['Shipping Type'].value_counts())
plt.figure(figsize= (12,8))
plt.title("Count Of Shipping Type")
ax = sns.countplot(df , x="Shipping Type" , palette= "plasma" , order= Shipping_Type_order)
plt.xlabel("Shipping Type")
plt.ylabel("Count")
plt.xticks(rotation = 45 )
for i in ax.containers: 
    ax.bar_label(i)
plt.savefig("Count Of Shipping Type.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Shipping Type
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Shipping Type" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#     Shipping Type  Purchase Amount (USD)
# 0  2-Day Shipping              60.733652
# 1         Express              60.475232
# 2   Free Shipping              60.410370
# 5    Store Pickup              59.893846
# 3    Next Day Air              58.631173
# 4        Standard              58.460245

# %%
fig = px.bar(x , x = "Shipping Type" , y = "Purchase Amount (USD)" , color= "Shipping Type", title= "Average Purchase Amount (USD) For Each Shipping Type" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# ### Average Purchase Amount by Shipping Type
# - **Number of purchases by shipping type:**
#   - **Free Shipping**: 675 purchases
#   - **Standard**: 654 purchases
#   - **Store Pickup**: 650 purchases
#   - **Next Day Air**: 648 purchases
#   - **Express**: 646 purchases
#   - **2-Day Shipping**: 627 purchases
#
# - **Average purchase amount by shipping type:**
#   - **2-Day Shipping**: 60.73 USD
#   - **Express**: 60.48 USD
#   - **Free Shipping**: 60.41 USD
#   - **Store Pickup**: 59.89 USD
#   - **Next Day Air**: 58.63 USD
#   - **Standard**: 58.46 USD
#
# ### Insights
#
# - **Free Shipping is the most commonly used shipping method**, followed closely by Standard and Store Pickup.
# - **Highest average spending occurs with 2-Day Shipping, Express, and Free Shipping**, suggesting that faster or more convenient shipping options may encourage higher-value purchases.
# - **Next Day Air and Standard** have slightly lower average purchase amounts, indicating they may be used more for **smaller or routine orders**.
# - Overall, **shipping type has a minor effect on purchase amount**, with averages ranging from **58.46 USD to 60.73 USD**.

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
Preferred_Payment_Method_order = df['Preferred Payment Method'].value_counts().index
print(df['Preferred Payment Method'].value_counts())
plt.figure(figsize= (12,8))
plt.title("Count Of Preferred Payment Method")
ax = sns.countplot(df , x="Preferred Payment Method" , palette= "plasma" , order= Preferred_Payment_Method_order)
plt.xlabel("Preferred Payment Method")
plt.ylabel("Count")
plt.xticks(rotation = 45 )
for i in ax.containers: 
    ax.bar_label(i)
plt.savefig("Count Of Preferred Payment Method.png" , dpi = 300 , bbox_inches = "tight")
plt.show()

# %%
x = df.pivot_table(index= "Preferred Payment Method" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x

# %%
fig = px.bar(x , x = "Preferred Payment Method" , y = "Purchase Amount (USD)" , color= "Preferred Payment Method", title= "Average Purchase Amount (USD) For Each Preferred Payment Method" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# ### Average Purchase Amount by Preferred Payment Method
# - **Number of customers by preferred payment method:**
#   - **PayPal**: 677 customers
#   - **Credit Card**: 671 customers
#   - **Cash**: 670 customers
#   - **Debit Card**: 636 customers
#   - **Venmo**: 634 customers
#   - **Bank Transfer**: 612 customers
#
# - **Average purchase amount by preferred payment method:**
#   - **Debit Card**: 60.92 USD
#   - **Credit Card**: 60.07 USD
#   - **Bank Transfer**: 59.71 USD
#   - **Cash**: 59.70 USD
#   - **PayPal**: 59.25 USD
#   - **Venmo**: 58.95 USD
#
# ### Insights
#
# - **PayPal, Credit Card, and Cash are the most preferred payment methods**, indicating customer comfort with both digital and cash options.
# - **Highest average spending occurs with Debit Card and Credit Card**, suggesting customers using these methods may purchase **higher-value items**.
# - **Venmo and PayPal**, while frequently preferred, have slightly **lower average purchase amounts**, indicating they may be used for **smaller or casual purchases**.
# - Overall, **preferred payment method slightly influences average spending**, but the variation is modest, ranging from **58.95 USD to 60.92 USD**.

# %%
Frequency_of_Purchases_order = df['Frequency of Purchases'].value_counts().index
print(df['Frequency of Purchases'].value_counts())
plt.figure(figsize= (12,8))
plt.title("Frequency of Purchases")
ax = sns.countplot(df , x="Frequency of Purchases"  , palette= "plasma" , order= Frequency_of_Purchases_order)
plt.xlabel("Frequency of Purchases")
plt.ylabel("Count")
plt.xticks(rotation = 45 )
for i in ax.containers: 
    ax.bar_label(i)
plt.savefig("Frequency of Purchases.png" , dpi = 300 , bbox_inches = "tight")
plt.show()
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
x = df.pivot_table(index= "Frequency of Purchases" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#   Frequency of Purchases  Purchase Amount (USD)
# 1              Bi-Weekly              60.694698
# 0               Annually              60.173077
# 2         Every 3 Months              60.082192
# 5              Quarterly              59.984014
# 4                Monthly              59.330922
# 3            Fortnightly              59.053506
# 6                 Weekly              58.972171

# %%
fig = px.bar(x , x = "Frequency of Purchases" , y = "Purchase Amount (USD)" , color= "Frequency of Purchases", title= "Average Purchase Amount (USD) For Each Frequency of Purchases" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# ### Average Purchase Amount by Frequency of Purchases
# - **Number of customers by purchase frequency:**
#   - **Every 3 Months**: 584 customers
#   - **Annually**: 572 customers
#   - **Quarterly**: 563 customers
#   - **Monthly**: 553 customers
#   - **Bi-Weekly**: 547 customers
#   - **Fortnightly**: 542 customers
#   - **Weekly**: 539 customers
#
# - **Average purchase amount by purchase frequency:**
#   - **Bi-Weekly**: 60.69 USD
#   - **Annually**: 60.17 USD
#   - **Every 3 Months**: 60.08 USD
#   - **Quarterly**: 59.98 USD
#   - **Monthly**: 59.33 USD
#   - **Fortnightly**: 59.05 USD
#   - **Weekly**: 58.97 USD
#
# ### Insights
#
# - **Customers purchasing bi-weekly tend to spend the most per purchase**, while weekly purchasers spend the least on average.
# - **Annual and every-3-months purchases also have relatively high average spending**, suggesting that **less frequent purchases are often higher in value**.
# - Frequent purchases (weekly, fortnightly, monthly) have slightly lower average amounts, indicating **smaller, routine transactions**.
# - Overall, **purchase frequency moderately influences average spending**, with values ranging from **58.97 USD to 60.69 USD**, showing a consistent mid-range spending pattern across frequencies.

# %%
x = df.pivot_table(index= "Location" , values="Purchase Amount (USD)" , aggfunc= "mean")
x.reset_index(inplace= True)
x.sort_values(by = "Purchase Amount (USD)" , ascending= False , inplace= True)
x
# Out:
#           Location  Purchase Amount (USD)
# 1           Alaska              67.597222
# 37    Pennsylvania              66.567568
# 2          Arizona              66.553846
# 47   West Virginia              63.876543
# 27          Nevada              63.379310
# 46      Washington              63.328767
# 33    North Dakota              62.891566
# 45        Virginia              62.883117
# 43            Utah              62.577465
# 21        Michigan              62.095890
# 41       Tennessee              61.974026
# 30      New Mexico              61.901235
# 38    Rhode Island              61.444444
# 42           Texas              61.194805
# 3         Arkansas              61.113924
# 12        Illinois              61.054348
# 23     Mississippi              61.037500
# 20   Massachusetts              60.888889
# 14            Iowa              60.884058
# 32  North Carolina              60.794872
# 49         Wyoming              60.690141
# ...

# %%
fig = px.bar(x.head(10) , x = "Location" , y = "Purchase Amount (USD)" , color= "Location", title= "Top 10 Locations Purchased Amount" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %%
fig = px.bar(x.tail(10) , x = "Location" , y = "Purchase Amount (USD)" , color= "Location", title= "Bottom 10 Locations Purchased Amount" , color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()

# %% [markdown]
# ### Top 10 and Bottom 10 Locations by Average Purchase Amount
#
# **Top 10 Locations (Highest Average Purchase Amount):**
#
# | Location       | Average Purchase Amount (USD) |
# |----------------|-------------------------------|
# | Alaska         | 67.60                         |
# | Pennsylvania   | 66.57                         |
# | Arizona        | 66.55                         |
# | West Virginia  | 63.88                         |
# | Nevada         | 63.38                         |
# | Washington     | 63.33                         |
# | North Dakota   | 62.89                         |
# | Virginia       | 62.88                         |
# | Utah           | 62.58                         |
# | Michigan       | 62.10                         |
#
# **Bottom 10 Locations (Lowest Average Purchase Amount):**
#
# | Location       | Average Purchase Amount (USD) |
# |----------------|-------------------------------|
# | Delaware       | 55.33                         |
# | Kansas         | 54.56                         |
# | Connecticut    | 54.18                         |
# | Maryland       | 55.76                         |
# | Florida        | 55.85                         |
# | Wisconsin      | 55.95                         |
# | Kentucky       | 55.72                         |
# | Maine          | 56.99                         |
# | New Jersey     | 56.75                         |
# | Minnesota      | 56.56                         |
#
# ### Insights
#
# - **Alaska, Pennsylvania, and Arizona** show the **highest average spending**, indicating that customers in these states tend to purchase higher-value items.
# - **Connecticut, Kansas, and Delaware** have the **lowest average spending**, suggesting smaller or more budget-conscious purchases.
# - Overall, there is a **moderate variation in average purchase amounts across states**, ranging roughly from **54.18 USD to 67.60 USD**.

# %%
correlation = df.corr(numeric_only= True)
sns.heatmap(correlation , annot= True , cmap= "plasma")
# Out:
# <Axes: >
