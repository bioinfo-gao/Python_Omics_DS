# %% [markdown]
# 一、导入
# 1.导入matplotlib库简写为plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2.用plot方法画出x=(0,10)间sin的图像

# %%
x = np.linspace(0, 10, 30)
plt .plot(x,np.sin(x))

# %% [markdown]
# 3.用点加线的方式画出x=(0,10)间sin的图像

# %%
plt.plot(x, np.sin(x), '-o') # 'o'表示使用圆点标记数据点

# %% [markdown]
# 5.用饼图的面积及颜色展示一组4维数据

# %%
# 创建一个伪随机数生成器的实例，并设置种子为0。
rng = np.random.RandomState(0)

# 生成一个包含100个随机数的一维数组，这些数服从标准正态分布（均值为0，方差为1）。
x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100) 
# plt.scatter()函数接收到这100个数值后，会使用cmap='viridis'这个颜色映射表（colormap）
# 将这些数值转换成具体的颜色。

sizes = 1000 * rng.rand(100)
# 将每个数乘以1000。这些结果值将决定每个点的大小。

# 调用scatter函数来绘制散点图。
# x: 指定所有点的x坐标。
# y: 指定所有点的y坐标。
# c=colors: 将colors数组中的值传递给参数c，用于指定每个点的颜色。matplotlib会根据cmap将这些数值映射成具体颜色。
# s=sizes: 将sizes数组中的值传递给参数s，用于指定每个点的面积大小。
# alpha=0.3: 设置所有点的透明度为30%（0.3），这样可以更容易地看到重叠的点。
# cmap='viridis': 指定使用的颜色映射表（colormap）为'viridis'。它会把colors数组中的数值（从0到1）映射为从紫色到黄色的渐变色。
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis') # <<==============

# 在图表的旁边添加一个颜色条（colorbar）。
# 这个颜色条会显示数值（来自colors数组）与实际颜色之间的对应关系。
plt.colorbar()
#  当你调用 plt.colorbar() 函数时，它会在你的图表上绘制一个颜色条。
# 同时，这个函数会创建并返回一个 Colorbar 对象。这个对象包含了颜色条的所有信息和属性。

# plt.colorbar(); 
# # very interesting, with ; the matplotlib,object will show up in jupyter notebook
# 分号 (;) 可以用来在同一行中分隔多条语句。然而，在Jupyter和IPython这样的环境中，它还有一个特殊的、更常见的用途：抑制当前行代码的输出。

# （可选，但在脚本中通常是必需的）显示生成的图形。
# plt.show()

# %% [markdown]
# 在进行数据可视化时，我们通常只关心生成的图像，而不关心绘图函数返回的对象本身。因此，在Jupyter环境中，为了保持输出的整洁，在绘图命令（尤其是单元格的最后一行）的末尾加上分号是一种非常普遍且推荐的做法。

# %% [markdown]
# 6.绘制一组误差为±0.8的数据的误差条图

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k') ;

# %% [markdown]
# 7.绘制一个柱状图

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [3, 1, 4, 5, 8, 9, 7, 2]
label=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
plt.bar(x,y,tick_label = label);
#plt.plot(x,y,marker='*');

# %% [markdown]
# 8.绘制一个水平方向柱状图

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [3, 1, 4, 5, 8, 9, 7, 2]
label=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
#   9.54631049e-01  1.98579570e-01  1.39865518e+00  1.00582551e+00
#  -2.03449175e+00  1.30338653e+00 -9.31934690e-01  1.05178489e+00
#  -1.21237570e+00  1.17493777e+00  2.10337156e-01  1.05246825e+00
#  -2.06035069e+00 -9.06078684e-01  2.09096953e-01  1.81453627e+00
#   8.58843682e-01 -1.32630227e+00  1.27969008e+00 -1.97883711e+00
#   2.25951035e+00 -7.82378450e-01  9.75702384e-02 -1.03289074e+00
#  -1.17731617e+00  9.20476148e-01 -3.05235097e-01  5.56267698e-01
#  -2.71936472e+00 -1.82238457e+00  7.65840597e-01  3.74502257e-01
#  -2.09236080e+00  2.37804042e-01 -1.00645577e+00 -1.42313419e+00
#  -3.98479208e-01 -7.97327630e-01  4.36899911e-01  1.06812662e+00
#  -8.90622456e-01 -1.67783999e+00 -1.15160676e+00 -3.70765505e-01
#   2.18973751e-01  1.66964015e-01 -3.33340701e-01  9.14583786e-01
#   1.45428681e+00 -2.75095269e-01 -1.71879650e-01  1.29031193e+00
#   5.51526109e-03  1.40733239e+00  8.76861512e-01  1.15846615e+00
#  -6.81500681e-01 -9.99915826e-01  8.75745477e-01 -5.65431681e-01
#   9.14602566e-01 -1.80484733e-01 -2.59534136e-01 -1.68502840e+00
#  -1.03161723e+00  8.55880379e-01  3.47502301e-01  2.18830396e+00
#  -1.81518696e-01  2.07299439e+00 -7.11319128e-01 -6.34146951e-01
#   2.26789730e-01 -1.13944578e+00  1.51739251e-01  3.40841365e-01
#   6.54556310e-01 -6.30357420e-01  8.47902653e-01  5.73977224e-01]

# %%
plt.hist(data); # plot histogram for continuous data, default 10 bins

# %%
plt.hist(data, bins=100); # plot histogram for continuous data

# %% [markdown]
# 10.设置直方图分30个bins,并设置为频率分布

# %%
plt.hist(data, bins=30,histtype='stepfilled', density=True) ;
#plt.show();

# %% [markdown]
# 11.在一张图中绘制3组不同的直方图,并设置透明度

# %%
x1 = np.random.normal(0, 0.8, 1000) # mean=0, std=0.8, 1000 samples
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(alpha=0.3, bins=40, density = True) # save keyword arguments in a dict
plt.hist(x1, **kwargs);
plt.hist(x2, **kwargs);
plt.hist(x3, **kwargs);

# %% [markdown]
# 12.绘制一张二维直方图

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal (mean, cov, 10000).T
plt.hist2d(x, y, bins=30);

# %% [markdown]
# 13.绘制一张设置网格大小为30的 <span style="color: orange;"> 六角形直方图 </span>

# %%
plt.hexbin(x, y, gridsize=30);

# %% [markdown]
# 三、自定义图表元素
# 14.绘制x=(0,10)间sin的图像,设置线性为虚线
# Guest Do

# %%
x = np.linspace(0, 10, 30)
plt.plot(x,np.sin(x))

# %%
x = np.linspace (0,10,100)
plt.plot(x,np.sin(x),'--') ;

# %% [markdown]
# 15.设置y轴显示范围为(-2.5,1.5)

# %%
X = np.linspace (0,10,100)
plt.plot(x,np.sin(x))
plt.ylim(-2.5,1.5);
