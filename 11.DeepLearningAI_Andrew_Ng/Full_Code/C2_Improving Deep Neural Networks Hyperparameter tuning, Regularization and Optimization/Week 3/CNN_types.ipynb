# %% [markdown]
# | 模型架构 | 发布年份 | 参数量 (Millions) | 计算量 (GFLOPs) | ImageNet Top-5 Error | 模型文件大小 (MB) |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **VGG-16** | 2014 | **138.0 M** | 15.5 | 8.1% | ~528 MB |
# | **GoogLeNet (v1)** | 2014 | **6.7 M** | **1.5** | **6.67%** | ~28 MB |
# | **Inception-v3** | 2015 | 23.8 M | 5.7 | 3.58% | ~92 MB |
# | **ResNet-50** | 2015 | 25.6 M | 3.8 | 3.57% | ~98 MB |
# | **Inception-v4** | 2016 | 42.7 M | 12.3 | **3.08%** | ~170 MB |
